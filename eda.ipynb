# %% [markdown]
# # Ladybug House Caregiver Analysis Survey
#
# ## By: Patrick L. Cavins, PhD and Heidi Blocker, PhD

# %% [markdown]
# ##  Exploratory Data Analysis
#
# ### Part 1:
#
# We have a caregiver survey which has over 100 questions. Many of the surveys are not complete, and we have no record if skip logic has been used at all.
#
# - What is the structure of the survey?
# - Classify the questions into some broad categories?
#
# ### Part 2:
#
# We are going to break the analysis up into the follow categories
#
# - Natural Language Processing
# - Quantitative Viz
# - Interactive Viz

# %%
## Import Libraries 

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importing the Data

# %%
full_lbh = pd.read_excel('./data/full_lbh_dataset.xlsx')

full_lbh.drop(columns='Unnamed: 0', inplace=True)

full_lbh.head()
# Out:
#              StartDate  Progress  Duration (in seconds)  Finished  \
# 0           Start Date  Progress  Duration (in seconds)  Finished
# 1  2017-05-08 17:21:36         1                      8     False
# 2  2016-10-13 16:39:15         1                      9     False
# 3  2017-02-02 19:11:25         1                     14     False
# 4  2016-10-01 06:11:15         1                     15     False
#
#                       Q148 Q130 Unnamed: 7  Exclusions_Q149  Exclusions_Q137  \
# 0                  Consent  NaN  Responded  Exclusions_Q149  Exclusions_Q137
# 1  Yes, I wish to continue  NaN          1              NaN              NaN
# 2  Yes, I wish to continue  NaN          1              NaN              NaN
# 3  Yes, I wish to continue  NaN          1              NaN              NaN
# 4  Yes, I wish to continue  NaN          1              NaN              NaN
#
#    Exclusions_Q18  ...                                               Q127  \
# ...

# %%
df_lbh = pd.read_csv('./data/lbh_data_exclusionsidentified_forpython.csv')

df_lbh.head()
# Out:
#                Q149 Q137  Q18                              Q16  Q17 Q134  Q19  \
# 0  Yes, in the past  Yes  Yes     Professional/hired caregiver  NaN  NaN  Yes
# 1  Yes, in the past  Yes  Yes                           Mother  NaN  Yes   No
# 2    Yes, currently  Yes  Yes                           Mother  NaN  NaN  NaN
# 3  Yes, in the past  Yes  Yes     Professional/hired caregiver  NaN  NaN  Yes
# 4  Yes, in the past  Yes  Yes  Family member other than parent  NaN  NaN  NaN
#
#                            Q20 Q20.1  Q20_1  ... Q126 Q127 Q128  Q129  Q132  \
# 0  We moved from another state   NaN    NaN  ...  NaN  NaN  NaN   NaN   NaN
# 1                          NaN   NaN    NaN  ...  NaN  NaN  NaN   NaN   NaN
# 2                          NaN   NaN    NaN  ...  NaN  NaN  NaN   NaN   NaN
# 3  We moved from another state   NaN    NaN  ...  NaN  NaN  NaN   NaN   NaN
# 4                          NaN   NaN    NaN  ...  NaN  NaN  NaN   NaN   NaN
#
#   Q133 Q130 Q136 Q134.1  Q120 - Topics
# ...

# %% [markdown]
# ### Make a table out of the questions

# %%
question_header = full_lbh.iloc[0:1]

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-c303e65cc0a8> in <module>()
# ----> 1 plt.table(question_header)
#
# TypeError: table() takes 0 positional arguments but 1 was given

# %%
## Results Summary

# We have 128 questions
